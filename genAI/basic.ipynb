# %% [markdown]
# | Command                 | Description                                                                                 |
# | ----------------------- | ------------------------------------------------------------------------------------------- |
# | ⁠ ollama init ⁠           | Initializes a new model project in the current directory.                                   |
# | ⁠ ollama run <model> ⁠    | Runs a model (downloads it if not already available).<br>Example: ⁠ ollama run llama3 ⁠       |
# | ⁠ ollama list ⁠           | Lists all locally downloaded models.                                                        |
# | ⁠ ollama pull <model> ⁠   | Downloads a model manually.<br>Example: ⁠ ollama pull mistral ⁠                               |
# | ⁠ ollama create <model> ⁠ | Creates a custom model using a Modelfile.<br>Example: ⁠ ollama create my-model -f Modelfile ⁠ |
# | ⁠ ollama delete <model> ⁠ | Deletes a model from your local machine.                                                    |
# | ⁠ ollama serve ⁠          | Starts the Ollama server (automatically runs in background normally).                       |
# | ⁠ ollama stop <model> ⁠   | Stops a running model.                                                                      |
# | ⁠ ollama help ⁠           | Displays all available commands and usage options.                                          |

# %%
import requests

# %%
OLLAMA_URL= "http://localhost:11434/api/generate"
MODEL="gemma3:latest"
prompt="Explain the cconcept of machine learning in simple terms"
payload={
    "model":MODEL,
    "prompt":prompt,
    "stream":False
}
response=requests.post(OLLAMA_URL,json=payload)

if  response.status_code==200:
    result=response.json()
    print("Response:\n",result["response"])
else:
    print("Error:",response.status_code,response.text)
# Out:
# Response:
#  Okay, let's break down machine learning in a way that's easy to understand.
#
# **Imagine you're teaching a dog a trick.**
#
# * **Traditional Programming:** You'd give the dog *very specific* instructions: "If I say 'Sit', then lower your bottom to the ground."  It has to follow those instructions *exactly*. If anything deviates, it doesn't work.
#
# * **Machine Learning:** Instead of telling the dog *exactly* what to do, you show it lots of examples. You say "Sit!" and reward the dog when it sits correctly.  Over time, the dog *learns* what "Sit!" means based on the rewards and corrections. It figures out the pattern itself.
#
# **That's essentially what machine learning is:**
#
# **Machine learning is teaching computers to learn from data without being explicitly programmed.**
#
# Here's a more formal breakdown:
#
# 1. **Data:** You give the computer a huge amount of data. This could be anything – pictures of cats and dogs, customer purchase history, medical records, stock prices, etc.
#
# 2. **Algorithm:** The computer uses a special set of instructions called an “algorithm.” Think of this like a recipe. Different algorithms are good for different types of problems.
#
# 3. **Learning:** The algorithm analyzes the data and looks for patterns and relationships. It adjusts itself based on the data it sees.  It's essentially building a model.
#
# 4. **Prediction/Decision:** Once the model is trained (meaning it's learned from the data), you can give it new data, and it will use what it's learned to make predictions or decisions.
#
# **Here are some common examples:**
#
# * **Spam Filters:**  They learn to identify spam emails based on patterns in the words and sender information.
# * **Netflix Recommendations:** They learn your viewing preferences and recommend movies/shows you might like.
# * **Self-Driving Cars:** They learn to recognize traffic signs, pedestrians, and other vehicles by analyzing images from cameras.
# * **Voice Assistants (Siri, Alexa):** They learn to understand your voice commands.
#
#
#
# **Key takeaway:** Instead of telling a computer *how* to do something, you give it data and let it figure it out for itself.
#
# ---
#
# **Resources to Learn More:**
#
# * **Google's Machine Learning Crash Course:** [https://developers.google.com/machine-learning/crash-course](https://developers.google.com/machine-learning/crash-course)
# * **Khan Academy - Machine Learning:** [https://www.khanacademy.org/computing/machine-learning](https://www.khanacademy.org/computing/machine-learning)
#
#
# Would you like me to delve into a specific aspect of machine learning, like:
#
# *   Different types of machine learning (supervised, unsupervised, reinforcement)
# *   A particular algorithm (like linear regression or decision trees)?
