# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/Users/apple/Desktop/internship_2nd_year/projects/LaptopPredictor/laptopassignment.csv')

# %%
df.head()
# Out:
#    brand  processor_brand  processor_name  processor_gnrtn  ram_gb  ssd   hdd  \
# 0      0                0               0               10       4    0  1024
# 1      1                0               0               10       4    0  1024
# 2      1                0               0               10       4    0  1024
# 3      0                0               1               10       8  512     0
# 4      0                0               2               99       4    0   512
#
#    graphic_card_gb  warranty  Touchscreen  Price  rating
# 0                0         0            0  34649       2
# 1                0         0            0  38999       3
# 2                0         0            0  39999       3
# 3                2         0            0  69990       3
# 4                0         0            0  26990       3

# %%
df.isnull().sum()
# Out:
# brand              0
# processor_brand    0
# processor_name     0
# processor_gnrtn    0
# ram_gb             0
# ssd                0
# hdd                0
# graphic_card_gb    0
# warranty           0
# Touchscreen        0
# Price              0
# rating             0
# dtype: int64

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb    ssd  \
# 0    False            False           False            False   False  False
# 1    False            False           False            False   False  False
# 2    False            False           False            False   False  False
# 3    False            False           False            False   False  False
# 4    False            False           False            False   False  False
# ..     ...              ...             ...              ...     ...    ...
# 777  False            False           False            False   False  False
# 778  False            False           False            False   False  False
# 779  False            False           False            False   False  False
# 780  False            False           False            False   False  False
# 781  False            False           False            False   False  False
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#             brand  processor_brand  processor_name  processor_gnrtn  \
# count  782.000000       782.000000      782.000000       782.000000
# mean     2.525575         0.282609        2.773657        34.979540
# std      2.278606         0.501653        2.972115        39.708955
# min      0.000000         0.000000        0.000000         4.000000
# 25%      0.000000         0.000000        1.000000        10.000000
# 50%      2.000000         0.000000        1.000000        11.000000
# 75%      5.000000         1.000000        4.000000        99.000000
# max      7.000000         2.000000       10.000000        99.000000
#
#            ram_gb         ssd          hdd  graphic_card_gb    warranty  \
# count  782.000000   782.00000   782.000000       782.000000  782.000000
# mean     8.685422   454.87468   229.156010         1.240409    0.723785
# std      4.418651   320.98166   414.289319         2.057061    0.599122
# ...

# %%
x = df.drop(columns=['Price'])
y = df['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
rfr = RandomForestRegressor(n_estimators=100, random_state=42)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rfr.score(x_test,y_test)
# Out:
# 0.7231488779886113

# %%
rfr.score(x_train,y_train)
# Out:
# 0.9398988755011844

# %%
prdct = rfr.predict(x_test)
print("Predictions:", prdct)
# Out:
# Predictions: [ 34024.915      212214.42857143  65627.07626587  76669.1
#   44419.38464286  72090.8         64646.56883333  66986.60166667
#   72514.3825      78924.75       105421.28       111540.65833333
#   66986.60166667  39647.93       124478.57142857  39950.48166667
#  146949.80083333  39497.51666667  86207.11        48362.91416667
#   36989.83        72873.07        40120.35166667  93301.00416667
#   37620.08333333  91929.17857143  77683.185       51737.01833333
#   56853.835       40724.18       107001.1031746   41270.48809524
#   37580.16916667  79393.27       130599.18333333  94495.14666667
#   60835.05       101331.12083333  56734.33433333  80070.8668254
#   86480.07       128547.00555556  48050.701       54720.67871429
#   63081.865      128547.00555556  92617.17190476  54720.67871429
#   40724.18        80329.73        65627.07626587  66315.37333333
#   40877.04666667  72090.8         44879.7982381   71913.25666667
# ...

# %%
rfc=RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rfc.score(x_test,y_test)
# Out:
# 0.006369426751592357

# %%
rfc.score(x_train,y_train)
# Out:
# 0.784

# %%
prdct1 = rfr.predict(x_test)
print("Predictions:", prdct1)
# Out:
# Predictions: [ 34024.915      212214.42857143  65627.07626587  76669.1
#   44419.38464286  72090.8         64646.56883333  66986.60166667
#   72514.3825      78924.75       105421.28       111540.65833333
#   66986.60166667  39647.93       124478.57142857  39950.48166667
#  146949.80083333  39497.51666667  86207.11        48362.91416667
#   36989.83        72873.07        40120.35166667  93301.00416667
#   37620.08333333  91929.17857143  77683.185       51737.01833333
#   56853.835       40724.18       107001.1031746   41270.48809524
#   37580.16916667  79393.27       130599.18333333  94495.14666667
#   60835.05       101331.12083333  56734.33433333  80070.8668254
#   86480.07       128547.00555556  48050.701       54720.67871429
#   63081.865      128547.00555556  92617.17190476  54720.67871429
#   40724.18        80329.73        65627.07626587  66315.37333333
#   40877.04666667  72090.8         44879.7982381   71913.25666667
# ...

# %%
import joblib 
joblib.dump(rfc , 'Lmodel.lb')
# Out:
# ['Lmodel.lb']

# %%
model =joblib.load('Lmodel.lb')

# %%
model.predict(x_test)
# Out:
# array([ 33990, 225990,  72500,  79990,  43590,  70980,  40590,  66999,
#         57990,  79990, 102551,  99990,  66999,  35990, 114990,  38999,
#        102990,  40200,  94190,  48900,  35990,  76012,  35990,  94990,
#         39998,  84990,  73400,  49990,  58990,  39490, 101990,  40990,
#         35990,  79990, 119990,  92990,  59990, 116990,  48490,  73999,
#         86990, 121990,  69267,  52990,  64990, 121990,  84990,  52990,
#         39490,  74798,  72500,  59900,  39990,  70980,  44690,  72990,
#         35990, 119990,  69490,  72964, 184990,  38490,  82990,  39990,
#         45990,  67500, 106990,  60990,  33690,  56990, 141990,  74999,
#         82990,  55990, 132790,  52632,  45990,  72990,  73063,  26990,
#         37990, 129990, 132790,  48990,  54990, 103990,  41490,  84190,
#         85990, 111999,  38799, 149990,  42490,  59990, 167990,  90190,
#         54990,  55999,  77990,  49990, 149990,  99990,  38940,  72500,
# ...

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb   ssd  \
# 0        0                0               0               10       4     0
# 1        1                0               0               10       4     0
# 2        1                0               0               10       4     0
# 3        0                0               1               10       8   512
# 4        0                0               2               99       4     0
# ..     ...              ...             ...              ...     ...   ...
# 777      0                1              10               99       4  1024
# 778      0                1              10               99       4  1024
# 779      0                1              10               99       4  1024
# 780      0                1              10               99       4  1024
# 781      1                1               3               10       8   512
#
#       hdd  graphic_card_gb  warranty  Touchscreen   Price  rating
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
import joblib

# (Re-train your model properly)
model = RandomForestRegressor()
model.fit(x_train, y_train)

# ✅ Save only the model, not prediction
joblib.dump(model, 'Lmodel.lb')
# Out:
# ['Lmodel.lb']
